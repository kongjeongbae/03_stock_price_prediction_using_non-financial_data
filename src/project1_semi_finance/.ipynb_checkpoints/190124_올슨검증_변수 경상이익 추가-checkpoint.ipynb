# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import pandas_datareader.data as web
import time
import tensorflow
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import logging
import math
import os
from sklearn.preprocessing import MinMaxScaler
from keras.utils import np_utils
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation
from keras import optimizers
from sklearn.metrics import mean_squared_error
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(23)

# %%
ohlson_info = pd.read_excel('./data/kospi200_4_ohlson.xlsx')
stock_info = pd.read_excel('./data/10년치_주가_LSTM_비율_올슨.xlsx')

# %%
ohlson_info['순자산'] = ohlson_info['자산(*)(요약)(IFRS연결)(백만원)'] - ohlson_info['부채(*)(요약)(IFRS연결)(백만원)']

# %%
del ohlson_info['자산(*)(요약)(IFRS연결)(백만원)']
del ohlson_info['부채(*)(요약)(IFRS연결)(백만원)']

# %%
ohlson_info.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '판매비와 관리비(물류원가 등 포함)(요약)(3개월)(IFRS연결)(백만원)',
#        '기타이익(요약)(3개월)(IFRS연결)(백만원)', '기타손실(요약)(3개월)(IFRS연결)(백만원)',
#        '법인세비용차감전순이익(손실)(요약)(3개월)(IFRS연결)(백만원)', '법인세비용(요약)(3개월)(IFRS연결)(백만원)',
#        '계속영업이익(손실)(요약)(3개월)(IFRS연결)(백만원)', '당기순이익(손실)(요약)(3개월)(IFRS연결)(백만원)',
#        '기타포괄손익(요약)(3개월)(IFRS연결)(백만원)', '총포괄손익(요약)(3개월)(IFRS연결)(백만원)',
#        '배당금(*)(요약)(IFRS)(백만원)', '순자산'],
#       dtype='object')

# %%
ohlson_info = ohlson_info[['회사명', '거래소코드', '회계년도','순자산', '판매비와 관리비(물류원가 등 포함)(요약)(3개월)(IFRS연결)(백만원)',
       '기타이익(요약)(3개월)(IFRS연결)(백만원)', '기타손실(요약)(3개월)(IFRS연결)(백만원)',
       '법인세비용차감전순이익(손실)(요약)(3개월)(IFRS연결)(백만원)', '법인세비용(요약)(3개월)(IFRS연결)(백만원)',
       '계속영업이익(손실)(요약)(3개월)(IFRS연결)(백만원)', '당기순이익(손실)(요약)(3개월)(IFRS연결)(백만원)',
       '기타포괄손익(요약)(3개월)(IFRS연결)(백만원)', '총포괄손익(요약)(3개월)(IFRS연결)(백만원)',
       '배당금(*)(요약)(IFRS)(백만원)']]

# %%
ohlson_info.columns = ['회사명', '거래소코드', '회계년도', '순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
       '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
       '계속영업이익(손실)(백만원)', '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)', '배당금(백만원)']

# %%
stock_info.columns
# Out:
# Index(['회사명', '거래소코드', '회계연도', '거래년도(*)', '거래월(*)', '거래일수', '최고가(원)', '최저가(원)',
#        '산술평균(원)', '종가(원)', '3개월뒤종가(원)', '거래량(주)', '거래대금(원)'],
#       dtype='object')

# %%
stock_info.columns = ['회사명', '거래소코드', '회계년도', '거래년도', '거래월', '거래일수', '최고가(원)', '최저가(원)',
       '산술평균(원)', '종가(원)', '3개월뒤종가(원)','거래량(주)', '거래대금(원)']

# %%
ohlson_data = pd.merge(ohlson_info, stock_info, on = ['회사명','거래소코드','회계년도'],how = 'left')

# %%
ohlson_data.isna().sum()
# Out:
# 회사명                           0
# 거래소코드                         0
# 회계년도                          0
# 순자산(백만원)                    227
# 판매비와 관리비(물류원가 등 포함)(백만원)    751
# 기타이익(백만원)                   751
# 기타손실(백만원)                   751
# 법인세비용차감전순이익(백만원)            751
# 법인세비용(백만원)                  751
# 계속영업이익(손실)(백만원)             751
# 당기순이익(백만원)                  751
# 기타포괄손익(백만원)                 751
# 총포괄손익(백만원)                  751
# 배당금(백만원)                      4
# 거래년도                        152
# 거래월                         152
# 거래일수                        152
# 최고가(원)                      152
# 최저가(원)                      152
# 산술평균(원)                     152
# 종가(원)                       152
# 3개월뒤종가(원)                   343
# 거래량(주)                      152
# 거래대금(원)                     152
# dtype: int64

# %% [markdown]
# # NA 값 있는 행 삭제

# %%
ohlson_data_non_na = ohlson_data[ohlson_data['기타이익(백만원)'].isna() == False]
ohlson_data_non_na = ohlson_data_non_na[ohlson_data_non_na['순자산(백만원)'].isna() == False]
ohlson_data_non_na = ohlson_data_non_na[ohlson_data_non_na['거래년도'].isna() == False]
ohlson_data_non_na = ohlson_data_non_na[ohlson_data_non_na['3개월뒤종가(원)'].isna() == False]

# %%
ohlson_data_non_na.isna().sum()
# Out:
# 회사명                         0
# 거래소코드                       0
# 회계년도                        0
# 순자산(백만원)                    0
# 판매비와 관리비(물류원가 등 포함)(백만원)    0
# 기타이익(백만원)                   0
# 기타손실(백만원)                   0
# 법인세비용차감전순이익(백만원)            0
# 법인세비용(백만원)                  0
# 계속영업이익(손실)(백만원)             0
# 당기순이익(백만원)                  0
# 기타포괄손익(백만원)                 0
# 총포괄손익(백만원)                  0
# 배당금(백만원)                    0
# 거래년도                        0
# 거래월                         0
# 거래일수                        0
# 최고가(원)                      0
# 최저가(원)                      0
# 산술평균(원)                     0
# 종가(원)                       0
# 3개월뒤종가(원)                   0
# 거래량(주)                      0
# 거래대금(원)                     0
# dtype: int64

# %%
ohlson_data_non_na.head()
# Out:
#           회사명   거래소코드     회계년도   순자산(백만원)  판매비와 관리비(물류원가 등 포함)(백만원)  \
# 0  (주)BNK금융지주  138930  2011/12  2954948.0                  162799.0
# 1  (주)BNK금융지주  138930  2012/12  3255216.0                  174999.0
# 2  (주)BNK금융지주  138930  2013/12  3600865.0                  178115.0
# 3  (주)BNK금융지주  138930  2014/12  5463944.0                  323601.0
# 4  (주)BNK금융지주  138930  2015/12  6190683.0                  337719.0
#
#    기타이익(백만원)  기타손실(백만원)  법인세비용차감전순이익(백만원)  법인세비용(백만원)  계속영업이익(손실)(백만원)  \
# 0     2432.0     6144.0          107555.0     28290.0          79264.0
# 1      740.0     5772.0           68185.0     16119.0          52065.0
# 2     5704.0     6394.0           26775.0      5354.0          21420.0
# 3     6054.0    19516.0          500118.0      1912.0         498205.0
# 4    10084.0    16622.0           37321.0     15367.0          21954.0
#
#        ...         거래년도   거래월  거래일수   최고가(원)   최저가(원)  산술평균(원)    종가(원)  \
# 0      ...       2011.0  12.0  21.0  11950.0  10300.0  11126.0  11050.0
# 1      ...       2012.0  12.0  18.0  13900.0  11900.0  12900.0  13200.0
# 2      ...       2013.0  12.0  20.0  16500.0  14950.0  15663.0  16000.0
# 3      ...       2014.0  12.0  21.0  15900.0  14250.0  15114.0  14500.0
# 4      ...       2015.0  12.0  21.0   9700.0   8180.0   8716.0   8420.0
#
#    3개월뒤종가(원)      거래량(주)       거래대금(원)
# 0    13300.0  16665990.0  1.857773e+09
# 1    15300.0   9487437.0  1.226757e+09
# 2    15050.0  11624471.0  1.819181e+09
# 3    15200.0   8931317.0  1.340248e+09
# 4     9700.0  33371878.0  2.902300e+09
#
# [5 rows x 24 columns]

# %%
ohlson_data_non_na.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
#        '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
#        '계속영업이익(손실)(백만원)', '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)',
#        '배당금(백만원)', '거래년도', '거래월', '거래일수', '최고가(원)', '최저가(원)', '산술평균(원)',
#        '종가(원)', '3개월뒤종가(원)', '거래량(주)', '거래대금(원)'],
#       dtype='object')

# %%
ohlson_data = ohlson_data_non_na

# %%
ohlson_data
# Out:
#               회사명   거래소코드     회계년도    순자산(백만원)  판매비와 관리비(물류원가 등 포함)(백만원)  \
# 0      (주)BNK금융지주  138930  2011/12   2954948.0                  162799.0
# 1      (주)BNK금융지주  138930  2012/12   3255216.0                  174999.0
# 2      (주)BNK금융지주  138930  2013/12   3600865.0                  178115.0
# 3      (주)BNK금융지주  138930  2014/12   5463944.0                  323601.0
# 4      (주)BNK금융지주  138930  2015/12   6190683.0                  337719.0
# 5      (주)BNK금융지주  138930  2016/12   7087153.0                  344820.0
# 11       (주)DB하이텍     990  2011/12    308062.0                  127164.0
# 12       (주)DB하이텍     990  2012/12    290893.0                  112405.0
# 13       (주)DB하이텍     990  2013/12    204757.0                   25042.0
# 14       (주)DB하이텍     990  2014/12    120703.0                   22435.0
# 15       (주)DB하이텍     990  2015/12    254058.0                   31114.0
# 16       (주)DB하이텍     990  2016/12    341918.0                   34247.0
# 21      (주)KB금융지주  105560  2011/12  23099795.0                 1084244.0
# 22      (주)KB금융지주  105560  2012/12  24704040.0                  878738.0
# 23      (주)KB금융지주  105560  2013/12  25652831.0                 1025040.0
# 24      (주)KB금융지주  105560  2014/12  27512672.0                 1036785.0
# 25      (주)KB금융지주  105560  2015/12  28902722.0                 1079290.0
# 26      (주)KB금융지주  105560  2016/12  31261403.0                 2110717.0
# 32        (주)강원랜드   35250  2011/12   2257363.0                   52081.0
# 33        (주)강원랜드   35250  2012/12   2372027.0                   51243.0
# 34        (주)강원랜드   35250  2013/12   2517697.0                   58730.0
# 35        (주)강원랜드   35250  2014/12   2705357.0                   60766.0
# 36        (주)강원랜드   35250  2015/12   2997755.0                   70805.0
# 37        (주)강원랜드   35250  2016/12   3252728.0                   68936.0
# 43         (주)녹십자    6280  2011/12    630281.0                   52472.0
# 44         (주)녹십자    6280  2012/12    685234.0                   59083.0
# 45         (주)녹십자    6280  2013/12    839409.0                   55374.0
# 46         (주)녹십자    6280  2014/12    920626.0                   62302.0
# 47         (주)녹십자    6280  2015/12    997704.0                   78180.0
# 48         (주)녹십자    6280  2016/12   1059011.0                   77218.0
# ...           ...     ...      ...         ...                       ...
# 2014      현대위아(주)   11210  2014/12   2848873.0                   88156.0
# 2022  149000.0   152500.0   8425412.0  1.278290e+10
# 2023  146000.0   158500.0   8047692.0  1.135562e+10
# 2029   95700.0   102000.0   9394477.0  9.416304e+09
# 2031   86300.0    68800.0   4753998.0  3.967553e+09
# 2032   63500.0    73000.0   4972025.0  3.194969e+09
# 2033   49950.0    55500.0   7848195.0  4.042550e+09
# 2034   57000.0    57900.0  12748397.0  7.061641e+09
# 2036   87800.0    81000.0   6799905.0  5.780316e+09
# 2040  257000.0   321500.0   6076281.0  1.679775e+10
# 2042  257000.0   211000.0   3716221.0  9.432501e+09
# 2044   87800.0   106500.0   5270280.0  4.754179e+09
# 2045  145500.0   165000.0   3556884.0  5.370693e+09
# 2046  100500.0   242000.0   5693198.0  6.698123e+09
# 2047  115000.0   122000.0   4975997.0  6.033669e+09
# 2054   31750.0    30300.0   5526162.0  1.757455e+09
# 2055   26000.0    24800.0   4317963.0  1.125621e+09
# 2056   36050.0    33200.0   4716417.0  1.602384e+09
# 2057   31500.0    34100.0   6909629.0  2.331518e+09
# 2059   32600.0    47000.0   7867907.0  2.605877e+09
# 2063   19950.0    21300.0   3024085.0  6.090894e+08
# 2064   25900.0    24050.0   1908231.0  4.850695e+08
# 2065   24000.0    21550.0   1338596.0  3.150435e+08
# 2066   25100.0    25550.0   3707405.0  9.909729e+08
# 2067   15300.0    19200.0   4641873.0  7.134212e+08
# 2068   21700.0    23800.0   1703099.0  3.882827e+08
#
# [1032 rows x 24 columns]

# %%
ohlson_data.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
#        '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
#        '계속영업이익(손실)(백만원)', '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)',
#        '배당금(백만원)', '거래년도', '거래월', '거래일수', '최고가(원)', '최저가(원)', '산술평균(원)',
#        '종가(원)', '3개월뒤종가(원)', '거래량(주)', '거래대금(원)'],
#       dtype='object')

# %%
#ohlson_data = ohlson_data[['회사명', '거래소코드', '회계년도', '순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
#        '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
#        '계속영업이익(손실)(백만원)', '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)',
#        '배당금(백만원)', '3개월뒤종가(원)']]
# Out:
#   File "<ipython-input-20-e9666db39246>", line 2
#     '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 경상이익 만들기

# %%
ohlson_data["경상이익"] = ohlson_data['계속영업이익(손실)(백만원)']+ ohlson_data['기타이익(백만원)']- ohlson_data['기타손실(백만원)']
# ohlson_data = ohlson_data[['회사명', '거래소코드', '회계년도', '순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
#        '기타이익(백만원)', '기타손실(백만원)', '법인세비용차감전순이익(백만원)', '법인세비용(백만원)',
#        '계속영업이익(손실)(백만원)', '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)',
#        '배당금(백만원)', '3개월뒤종가(원)']]

# %%
ohlson_data = ohlson_data[['회사명', '거래소코드', '회계년도', '순자산(백만원)', '경상이익', '배당금(백만원)', '3개월뒤종가(원)']]

# %%
ohlson_data.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도',
# 2029      현대제철(주)    4020  2011/12   9118862.0   272767.0   42143.0   102000.0
# 2031      현대제철(주)    4020  2013/12  13364683.0   271383.0   57939.0    68800.0
# 2032      현대제철(주)    4020  2014/12  13814787.0   231082.0   86909.0    73000.0
# 2033      현대제철(주)    4020  2015/12  15519999.0   233887.0   97772.0    55500.0
# 2034      현대제철(주)    4020  2016/12  16363639.0   101341.0   98453.0    57900.0
# 2036      현대제철(주)    4020  2012/12   9830927.0   218471.0   42143.0    81000.0
# 2040     현대중공업(주)    9540  2011/12  18176519.0  -697335.0  245154.0   321500.0
# 2042     현대중공업(주)    9540  2013/12  19029592.0  -568691.0  122577.0   211000.0
# 2044     현대중공업(주)    9540  2015/12  15426104.0  -905556.0       0.0   106500.0
# 2045     현대중공업(주)    9540  2016/12  17786562.0    27427.0       0.0   165000.0
# 2046     현대중공업(주)    9540  2017/12  12372038.0  -846342.0       0.0   242000.0
# 2047     현대중공업(주)    9540  2014/12  16638576.0   550701.0       0.0   122000.0
# 2054  현대해상화재보험(주)    1450  2013/03   2150671.0    43477.0   84435.0    30300.0
# 2055  현대해상화재보험(주)    1450  2014/12   2372322.0    49247.0   60311.0    24800.0
# 2056  현대해상화재보험(주)    1450  2015/12   2502694.0   -44200.0   59802.0    33200.0
# 2057  현대해상화재보험(주)    1450  2016/12   2848168.0    47648.0  107643.0    34100.0
# 2059  현대해상화재보험(주)    1450  2012/03   1781229.0    87855.0  108560.0    47000.0
# 2063       휴켐스(주)   69260  2011/12    455899.0    51538.0   28615.0    21300.0
# 2064       휴켐스(주)   69260  2012/12    460490.0    46081.0   28313.0    24050.0
# 2065       휴켐스(주)   69260  2013/12    463553.0    12257.0   29536.0    21550.0
# 2066       휴켐스(주)   69260  2014/12    473094.0     7732.0   21659.0    25550.0
# 2067       휴켐스(주)   69260  2015/12    472874.0     4543.0   19335.0    19200.0
# 2068       휴켐스(주)   69260  2016/12    493309.0     -536.0   19288.0    23800.0
#
# [1032 rows x 7 columns]

# %% [markdown]
# # 회사별로 리스트에 넣기

# %%
list_code = list(set(ohlson_data['거래소코드']))
list_company = list(set(ohlson_data['회사명']))

# %%
list_company1 = []
for i in range(len(list_code)):
    a = ohlson_data[ohlson_data['거래소코드'] == list_code[i]]
    list_company1.append(a)

# %% [markdown]
# # 자료 개수가 같은 것만 모으기 (행의 개수: 7 / 11~17년)

# %%
list_company2 = []
for i in range(len(list_company1)):
    a = len(list_company1[i])
    list_company2.append(a)
    
# list_company2 - len이 7이 젤 많음

# %%
list_company3 = []
for i in range(len(list_company2)):
    if list_company2[i] == 6:
        list_company3.append(list_company1[i])

# %%
len(list_company3) # 길이가 7이고 na값이 0인 기업들만 모아둠
# Out:
# 128

# %%
list_company3[1]
# Out:
#            회사명  거래소코드     회계년도   순자산(백만원)      경상이익  배당금(백만원)  3개월뒤종가(원)
# 910  금호석유화학(주)  11780  2011/12  1557078.0   51388.0   55948.0   142000.0
# 911  금호석유화학(주)  11780  2012/12  1658352.0 -120722.0   55948.0   105500.0
# 912  금호석유화학(주)  11780  2013/12  1559759.0 -224287.0   41999.0    87800.0
# 913  금호석유화학(주)  11780  2014/12  1641582.0   46957.0   41999.0    78500.0
# 914  금호석유화학(주)  11780  2015/12  1663750.0    6640.0   22470.0    58200.0
# 915  금호석유화학(주)  11780  2016/12  1727901.0  -45410.0   22096.0    78500.0

# %% [markdown]
# # 딥러닝 모델 구축

# %% [markdown]
# # 잘 안되서 0 들어가있는 기타이익, 기타손실 뺴보고 해봄 - 이것도 잘 안됨

# %%
# data = list_company3[1].loc[:,['순자산(백만원)', '판매비와 관리비(물류원가 등 포함)(백만원)',
#        '법인세비용차감전순이익(백만원)', '법인세비용(백만원)', '계속영업이익(손실)(백만원)',
#         '당기순이익(백만원)', '기타포괄손익(백만원)', '총포괄손익(백만원)', '배당금(백만원)', '3개월뒤종가(원)']]
# data

data = list_company3[1].loc[:,['순자산(백만원)','배당금(백만원)','3개월뒤종가(원)']]
data
# Out:
#       순자산(백만원)  배당금(백만원)  3개월뒤종가(원)
# 910  1557078.0   55948.0   142000.0
# 911  1658352.0   55948.0   105500.0
# 912  1559759.0   41999.0    87800.0
# 913  1641582.0   41999.0    78500.0
# 914  1663750.0   22470.0    58200.0
# 915  1727901.0   22096.0    78500.0

# %%
#data.to_csv("test.csv")

# %%
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility

x_data = data.loc[:,'순자산(백만원)':'배당금(백만원)']
x_data = x_data / 1000
y_data = pd.DataFrame(data.loc[:,'3개월뒤종가(원)'])


# Make sure the shape and data are OK
# print("x_data.shape : {}, \tlen(x_data) : {} \nx_data : \n{}".format(x_data.shape, len(x_data), x_data))
# print("-"*25)
# print("y_data.shape : {}  \ny_data : \n{}".format(y_data.shape, y_data))

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([2, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')


# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})

    if step % 100 == 0 or step < 10 :
        print("\nStep : {} \nCost : {} \nPrediction :\n{}".format(step, cost_val, hy_val))
# Out:
# Step : 0
# Cost : 9208186880.0
# Prediction :
# [[-468.53265]
#  [-497.79852]
#  [-464.81802]
#  [-488.46298]
#  [-488.58377]
#  [-507.00153]]
#
# Step : 1
# Cost : 23178059448320.0
# Prediction :
# [[4670641. ]
#  [4974134.5]
#  [4677564.5]
#  [4922768. ]
#  [4987644.5]
#  [5179860. ]]
#
# Step : 2
# Cost : 6.400764420921754e+16
# Prediction :
# [[-2.4079613e+08]
#  [-2.5644416e+08]
#  [-2.4115822e+08]
#  [-2.5380085e+08]
#  [-2.5715304e+08]
#  [-2.6706374e+08]]
#
# Step : 3
# Cost : 1.767672529445244e+20
# Prediction :
# [[1.2658855e+10]
#  [1.3481482e+10]
#  [1.2677880e+10]
#  [1.3342510e+10]
#  [1.3518722e+10]
#  [1.4039733e+10]]
#
# Step : 4
# Cost : 4.8817078008536854e+23
# Prediction :
# [[-6.6523687e+11]
#  [-7.0846684e+11]
#  [-6.6623675e+11]
#  [-7.0116383e+11]
#  [-7.1042394e+11]
#  [-7.3780370e+11]]
#
# Step : 5
# Cost : 1.3481606632913682e+27
# Prediction :
# [[3.4959188e+13]
#  [3.7230987e+13]
#  [3.5011730e+13]
#  [3.6847196e+13]
#  [3.7333835e+13]
#  [3.8772679e+13]]
#
# Step : 6
# Cost : 3.723159372044119e+30
# Prediction :
# [[-1.8371571e+15]
#  [-1.9565436e+15]
#  [-1.8399184e+15]
#  [-1.9363750e+15]
#  [-1.9619486e+15]
#  [-2.0375619e+15]]
#
# Step : 7
# Cost : 1.0282094138726885e+34
# Prediction :
# [[9.65453329e+16]
#  [1.02819275e+17]
#  [9.66904341e+16]
#  [1.01759372e+17]
#  [1.03103301e+17]
#  [1.07076893e+17]]
#
# Step : 8
# Cost : 2.8395634581135986e+37
# Prediction :
# [[-5.0736007e+18]
#  [-5.4033053e+18]
#  [-5.0812259e+18]
#  [-5.3476062e+18]
#  [-5.4182317e+18]
#  [-5.6270498e+18]]
#
# Step : 9
# Cost : inf
# Prediction :
# [[2.6662524e+20]
#  [2.8395171e+20]
#  [2.6702597e+20]
#  [2.8102467e+20]
#  [2.8473611e+20]
#  [2.9570983e+20]]
#
# Step : 100
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 200
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 300
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 400
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 500
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 600
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 700
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 800
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 900
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1000
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1100
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1200
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1300
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1400
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1500
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1600
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1700
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1800
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1900
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 2000
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]

# %% [markdown]
# ## 샤비어 함수

# %%
def xavier_init(n_inputs, n_outputs, uniform=True):
    if uniform:
        # 6 was used in the paper.
        init_range = tf.sqrt(6.0 / (n_inputs + n_outputs))
        return tf.random_uniform_initializer(-init_range, init_range)
    else:
        # 3 gives us approximately the same limints as above since this repicks
        # values greater than 2 standard deviations from the mean.
        stddev = tf.sqrt(3.0 / (n_inputs + n_outputs))
        return tf.truncated_normal_initializer(stddev=stddev)

# %% [markdown]
# ## 히든레이어 증가

# %%
import tensorflow as tf
import numpy as np
tf.reset_default_graph()

tf.set_random_seed(777)  # for reproducibility

x_data = data.loc[:,'순자산(백만원)':'배당금(백만원)']
x_data = x_data / 1000
y_data = pd.DataFrame(data.loc[:,'3개월뒤종가(원)'])


# Make sure the shape and data are OK
# print("x_data.shape : {}, \tlen(x_data) : {} \nx_data : \n{}".format(x_data.shape, len(x_data), x_data))
# print("-"*25)
# print("y_data.shape : {}  \ny_data : \n{}".format(y_data.shape, y_data))

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 9])
Y = tf.placeholder(tf.float32, shape=[None, 1])


W1 = tf.get_variable("W1", shape=[9, 32], initializer=tf.contrib.layers.xavier_initializer())
b1 = tf.Variable(tf.random_normal([32]))
L1 = tf.nn.relu(tf.matmul(X, W1) + b1)


W2 = tf.get_variable("W2", shape=[32, 64], initializer=tf.contrib.layers.xavier_initializer())
b2 = tf.Variable(tf.random_normal([64]))
L2 = tf.nn.relu(tf.matmul(L1, W2) + b2)

W3 = tf.get_variable("W3", shape=[64, 64], initializer=tf.contrib.layers.xavier_initializer())
b3 = tf.Variable(tf.random_normal([64]))
L3 = tf.nn.relu(tf.matmul(L2, W3) + b3)


W4 = tf.get_variable("W4", shape=[64, 64], initializer=tf.contrib.layers.xavier_initializer())
b4 = tf.Variable(tf.random_normal([64]))
L4 = tf.nn.relu(tf.matmul(L3, W4) + b4)


W5 = tf.get_variable("W5", shape=[64, 1], initializer=tf.contrib.layers.xavier_initializer())
b5 = tf.Variable(tf.random_normal([1]))
L5 = tf.nn.relu(tf.matmul(L4, W5) + b5)

hypothesis = tf.matmul(L4, W5) + b5



# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})

    if step % 100 == 0 or step < 10 :
        print("\nStep : {} \nCost : {} \nPrediction :\n{}".format(step, cost_val, hy_val))
# Out:
# Step : 0
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 2
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 3
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 4
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 5
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 6
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 7
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 8
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 9
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 100
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 200
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 300
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 400
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 500
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 600
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 700
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 800
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 900
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1000
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1100
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1200
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1300
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1400
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1500
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1600
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1700
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1800
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 1900
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
#
# Step : 2000
# Cost : nan
# Prediction :
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
